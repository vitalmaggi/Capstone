# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import pickle
import numpy as np
import matplotlib.pyplot as plt
import folium
# %matplotlib inline

# %%
fl_census_tracts = gpd.read_file("../data/cb_2018_12_bg_500k.shp")

# %%
fl_census_tracts.shape
# Out:
# (11409, 11)

# %%
fl_census_tracts.head()
# Out:
#   STATEFP COUNTYFP TRACTCE BLKGRPCE               AFFGEOID         GEOID NAME  \
# 0      12      011  010104        1  1500000US120110101041  120110101041    1
# 1      12      005  002705        1  1500000US120050027051  120050027051    1
# 2      12      057  006400        1  1500000US120570064001  120570064001    1
# 3      12      011  031205        1  1500000US120110312051  120110312051    1
# 4      12      103  020209        1  1500000US121030202091  121030202091    1
#
#   LSAD    ALAND   AWATER                                           geometry
# 0   BG   418681   571688  POLYGON ((-80.08052 26.32076, -80.07994 26.320...
# 1   BG  1127491  2212287  POLYGON ((-85.81744 30.18680, -85.81654 30.188...
# 2   BG   515469    99623  POLYGON ((-82.53514 27.92203, -82.53397 27.923...
# 3   BG   165404    17385  POLYGON ((-80.09006 26.25041, -80.08945 26.252...
# 4   BG   622112   298583  POLYGON ((-82.66337 27.70757, -82.66324 27.708...

# %%
fl_census_tracts.tail()
# Out:
#       STATEFP COUNTYFP TRACTCE BLKGRPCE               AFFGEOID         GEOID  \
# 11404      12      117  021306        4  1500000US121170213064  121170213064
# 11405      12      011  020315        1  1500000US120110203151  120110203151
# 11406      12      086  020000        2  1500000US120860200002  120860200002
# 11407      12      081  000309        2  1500000US120810003092  120810003092
# 11408      12      073  002006        3  1500000US120730020063  120730020063
#
#       NAME LSAD    ALAND  AWATER  \
# 11404    4   BG  1616003       0
# 11405    1   BG  1475922       0
# 11406    2   BG   252866       0
# 11407    2   BG   579457   79923
# 11408    3   BG   845510   20036
#
#                                                 geometry
# 11404  POLYGON ((-81.26267 28.67429, -81.26002 28.674...
# 11405  POLYGON ((-80.25313 26.25243, -80.25308 26.252...
# 11406  POLYGON ((-80.42993 25.60738, -80.42355 25.607...
# 11407  POLYGON ((-82.59587 27.44882, -82.59587 27.453...
# ...

# %%
fl_census_tracts.plot()
# Out:
# <AxesSubplot:>

# %%
fl_census_tracts.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - NAD83
# - bounds: (167.65, 14.92, -47.74, 86.46)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
fig, ax = plt.subplots(figsize=(20,20)) 
fl_census_tracts.plot(ax = ax);

# %%
fl_counties = gpd.read_file("../data/cb_2018_12_cousub_500k.shp")

# %%
fl_counties.shape
# Out:
# (316, 11)

# %%
fl_counties.head()
# Out:
#   STATEFP COUNTYFP COUSUBFP  COUSUBNS             AFFGEOID       GEOID  \
# 0      12      113    93659  02648027  0600000US1211393659  1211393659
# 1      12      089    93757  01935981  0600000US1208993757  1208993757
# 2      12      037    90039  01935684  0600000US1203790039  1203790039
# 3      12      047    91651  01935810  0600000US1204791651  1204791651
# 4      12      037    90936  01935754  0600000US1203790936  1203790936
#
#             NAME LSAD      ALAND     AWATER  \
# 0  Whiting Field   22   14880955      47852
# 1          Yulee   22  466658024   44077921
# 2   Apalachicola   22  205547942  659138101
# 3         Jasper   22  658855538    2557636
# 4      Eastpoint   22  789082145  188710722
#
#                                             geometry
# 0  POLYGON ((-87.04349 30.71134, -87.04189 30.711...
# 1  POLYGON ((-81.81174 30.70319, -81.80973 30.703...
# 2  MULTIPOLYGON (((-85.09717 29.62624, -85.09488 ...
# 3  POLYGON ((-83.09932 30.44630, -83.09785 30.445...
# ...

# %%
fl_counties.plot()
# Out:
# <AxesSubplot:>

# %%
fl_counties.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - NAD83
# - bounds: (167.65, 14.92, -47.74, 86.46)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
fig, ax = plt.subplots(figsize=(20,20),
                      edgecolor = 'black') 
fl_counties.plot(ax = ax);

# %%
fl_place = gpd.read_file("../data/cb_2018_12_place_500k.shp")

# %%
fl_place.shape
# Out:
# (919, 10)

# %%
fl_place.head()
# Out:
#   STATEFP PLACEFP   PLACENS          AFFGEOID    GEOID                  NAME  \
# 0      12   24000  02403640  1600000US1224000  1224000       Fort Lauderdale
# 1      12   42650  02406083  1600000US1242650  1242650                Malone
# 2      12   39750  02407489  1600000US1239750  1239750             Lazy Lake
# 3      12   35900  02405928  1600000US1235900  1235900  Jupiter Inlet Colony
# 4      12   63000  02405401  1600000US1263000  1263000        St. Petersburg
#
#   LSAD      ALAND     AWATER  \
# 0   25   89577004    4436116
# 1   43    7895501          0
# 2   47      59557          0
# 3   43     401131     137855
# 4   25  160184468  197307467
#
#                                             geometry
# 0  MULTIPOLYGON (((-80.14829 26.19879, -80.14740 ...
# 1  POLYGON ((-85.17643 30.97167, -85.16442 30.971...
# 2  POLYGON ((-80.14637 26.15752, -80.14412 26.157...
# 3  POLYGON ((-80.07881 26.95161, -80.07582 26.951...
# 4  MULTIPOLYGON (((-82.69547 27.66549, -82.69391 ...

# %%
fl_place.tail()
# Out:
#     STATEFP PLACEFP   PLACENS          AFFGEOID    GEOID             NAME  \
# 914      12   04070  02402665  1600000US1204070  1204070         Bay Hill
# 915      12   69250  01853255  1600000US1269250  1269250  Sun City Center
# 916      12   39950  02403227  1600000US1239950  1239950     Leisure City
# 917      12   23850  02583345  1600000US1223850  1223850       Fort Green
# 918      12   71569  02402923  1600000US1271569  1271569     The Hammocks
#
#     LSAD     ALAND   AWATER                                           geometry
# 914   57   6153015  2741155  POLYGON ((-81.52282 28.44281, -81.52311 28.468...
# 915   57  40798716  2206806  POLYGON ((-82.38953 27.70618, -82.38708 27.709...
# 916   57   8815896   173728  POLYGON ((-80.46238 25.48458, -80.45513 25.491...
# 917   57  10469295        0  POLYGON ((-81.96220 27.62739, -81.94659 27.627...
# 918   57  20430591   553746  POLYGON ((-80.47955 25.68074, -80.47872 25.683...

# %%
fl_place.plot()
# Out:
# <AxesSubplot:>

# %%
fl_place.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - NAD83
# - bounds: (167.65, 14.92, -47.74, 86.46)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
fig, ax = plt.subplots(figsize=(20,20),
                      edgecolor = 'black') 
fl_place.plot(ax = ax);

# %%
fl_irma = gpd.read_file("../data/AER_maxFlood_Irma_2017_SFL_0909-0911.shp")

# %%
fl_irma.shape
# Out:
# (3, 3)

# %%
fl_irma.head()
# Out:
#    OBJECTID                  Class  \
# 0         1               Flooding
# 1         2  Persistent Open Water
# 2         3         Woody Wetlands
#
#                                             geometry
# 0  MULTIPOLYGON (((-80.72833 25.00167, -80.72833 ...
# 1  MULTIPOLYGON (((-80.53000 25.00000, -80.53083 ...
# 2  MULTIPOLYGON (((-80.72917 25.00000, -80.73000 ...

# %%
fl_irma.plot()
# Out:
# <AxesSubplot:>

# %%
fl_irma.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
fig, ax = plt.subplots(figsize=(20,20),
                      edgecolor = 'black') 
fl_irma.plot(ax = ax);

# %%
fl_svi_2017 = gpd.read_file("../data/FLORIDA.shp")

# %%
fl_svi_2017.shape
# Out:
# (4215, 127)

# %%
fl_svi_2017.head()
# Out:
#                AFFGEOID TRACTCE  ST    STATE ST_ABBR STCNTY   COUNTY  \
# 0  1400000US12001000200  000200  12  Florida      FL  12001  Alachua
# 1  1400000US12001000301  000301  12  Florida      FL  12001  Alachua
# 2  1400000US12001000302  000302  12  Florida      FL  12001  Alachua
# 3  1400000US12001000400  000400  12  Florida      FL  12001  Alachua
# 4  1400000US12001000500  000500  12  Florida      FL  12001  Alachua
#
#           FIPS                                    LOCATION  AREA_SQMI  ...  \
# 0  12001000200     Census Tract 2, Alachua County, Florida   0.809273  ...
# 1  12001000301  Census Tract 3.01, Alachua County, Florida   0.957160  ...
# 2  12001000302  Census Tract 3.02, Alachua County, Florida   1.464848  ...
# 3  12001000400     Census Tract 4, Alachua County, Florida   2.324400  ...
# 4  12001000500     Census Tract 5, Alachua County, Florida   1.510726  ...
#
#    F_NOVEH  F_GROUPQ  F_THEME4  F_TOTAL  E_UNINSUR  M_UNINSUR  EP_UNINSUR  \
# ...

# %%
fl_svi_2017.plot()
# Out:
# <AxesSubplot:>

# %%
fl_svi_2017.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - NAD83
# - bounds: (167.65, 14.92, -47.74, 86.46)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
fig, ax = plt.subplots(figsize=(20,20),
                      edgecolor = 'black') 
fl_svi_2017.plot(ax = ax);

# %%
fl_shoreline = gpd.read_file("../data/Florida_Shoreline_(1_to_12%2C000_Scale).shp")

# %%
fl_shoreline.shape
# Out:
# (15470, 3)

# %%
fl_shoreline.head()
# Out:
#    OBJECTID  last_edite                                           geometry
# 0         1  1970-01-01  POLYGON ((-81.96357 24.52436, -81.96359 24.523...
# 1         2  1970-01-01  POLYGON ((-81.97077 24.52703, -81.97065 24.526...
# 2         3  1970-01-01  POLYGON ((-81.92254 24.52897, -81.92264 24.528...
# 3         4  1970-01-01  POLYGON ((-81.92284 24.52968, -81.92289 24.529...
# 4         5  1970-01-01  POLYGON ((-81.92643 24.53069, -81.92608 24.530...

# %%
fl_shoreline.tail()
# Out:
#        OBJECTID  last_edite                                           geometry
# 15465     15466  1970-01-01  POLYGON ((-81.48616 30.71197, -81.48612 30.711...
# 15466     15467  1970-01-01  POLYGON ((-81.52926 30.72149, -81.52908 30.721...
# 15467     15468  1970-01-01  POLYGON ((-81.65813 30.74421, -81.65824 30.744...
# 15468     15469  1970-01-01  POLYGON ((-81.65960 30.74672, -81.65967 30.746...
# 15469     15470  1970-01-01  POLYGON ((-81.61714 30.72177, -81.61712 30.721...

# %%
fl_shoreline.plot()
# Out:
# <AxesSubplot:>

# %%
fl_shoreline.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
fig, ax = plt.subplots(figsize=(20,20),
                      edgecolor = 'black') 
fl_shoreline.plot(ax = ax);

# %%
fl_lakes = gpd.read_file("../data/Florida_Lakes.shp")

# %%
fl_lakes.shape
# Out:
# (4243, 7)

# %%
fl_lakes.head()
# Out:
#       PERIMETER           NAME     COUNTY  OBJECTID     SHAPEAREA  \
# 0  11082.251506  Lake Maitland     ORANGE         1  1.818000e+06
# 1   2834.074075     Black Lake   ESCAMBIA         2  3.137978e+04
# 2  18768.273070   Lake Jackson  HIGHLANDS         3  1.360118e+07
# 3    493.278959  Halfmoon Lake   ESCAMBIA         4  6.337482e+03
# 4   5662.687648  Crescent Lake   ESCAMBIA         5  3.382422e+05
#
#        SHAPELEN                                           geometry
# 0  11082.250892  POLYGON ((-81.34814 28.62354, -81.34806 28.623...
# 1   2834.074076  POLYGON ((-87.42029 30.49087, -87.41992 30.490...
# 2  18768.273762  POLYGON ((-81.46141 27.46472, -81.46148 27.464...
# 3    493.278856  POLYGON ((-87.31310 30.74034, -87.31319 30.740...
# 4   5662.688705  POLYGON ((-87.27592 30.46921, -87.27624 30.469...

# %%
fl_lakes.plot()
# Out:
# <AxesSubplot:>

# %%
fl_lakes.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
fig, ax = plt.subplots(figsize=(20,20),
                      edgecolor = 'black') 
fl_lakes.plot(ax = ax);

# %%
fl_outstanding = gpd.read_file("../data/Outstanding_Florida_Waters.shp")

# %%
fl_outstanding.shape
# Out:
# (1041, 10)

# %%
fl_outstanding.head()
# Out:
#     TYPE                                NAME  \
# 0  Other          Florida Caverns State Park
# 1  Other   FLORIDA'S FIRST MAGNITUDE SPRINGS
# 2  Other          Florida Caverns State Park
# 3  Other   FLORIDA'S FIRST MAGNITUDE SPRINGS
# 4  Other  Three Rivers State Recreation Area
#
#                                             ALT_NAME RULE_ID  GIS_ID  \
# 0                                               None    None      55
# 1  FLORIDA FIRST MAGNITUDE SPRINGS CARL PROJ - BL...    None     164
# 2                                               None    None      55
# 3  FLORIDA FIRST MAGNITUDE SPRINGS CARL PROJ - BL...    None     164
# 4                                               None    None     103
#
#                 NOTES  OBJECTID     SHAPEAREA      SHAPELEN  \
# 0  BUREAU PARKS & REC         1  5.340970e+06  17917.816975
# 1              CARL96         2  1.159407e+06   6363.404401
# 2  BUREAU PARKS & REC         3  2.502908e+04   1705.016079
# ...

# %%
fl_outstanding.plot()
# Out:
# <AxesSubplot:>

# %%
fl_outstanding.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
fig, ax = plt.subplots(figsize=(20,20),
                      edgecolor = 'black') 
fl_outstanding.plot(ax = ax);

# %%
fl_demo_2015 = gpd.read_file("../data/c165dd75-413a-4eba-8123-f9e11072a0032020328-1-hdinsd.5w9f.shp")

# %%
fl_demo_2015.shape
# Out:
# (67, 27)

# %%
fl_demo_2015.head()
# Out:
#    OBJECTID         NAMELSAD  TotalPopul  Unemployme  Median_Hou  PercentFam  \
# 0         1  Hernando County      173119         8.2       41024        12.1
# 1         2   Wakulla County       30824         6.2       52691        11.5
# 2         3    Walton County       56590         5.6       43640        12.0
# 3         4   Volusia County      496268         5.9       42457        11.6
# 4         5    Hendry County       38346         9.1       35425        21.9
#
#    PercentF_1  PercentPop  PercentP_1  TotalPop_M  ...  PercentP_3  \
# 0        22.7        17.3        13.8       82934  ...         5.9
# 1        21.0        12.1         6.3       16894  ...         4.6
# 2        22.0        19.0        11.9       28793  ...         5.5
# 3        21.1        18.6        12.3      241922  ...         5.0
# 4        33.8        34.0        19.4       20730  ...         6.6
#
#    Pop_10to14  PercentP_4  Pop_15to19  PercentP_5  Pop_18andO  PercentP_6  \
# ...

# %%
fl_demo_2015.plot()
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(10,10))
fl_demo_2015.plot(column = 'TotalPopul',
                        cmap = 'viridis',
                        edgecolor = 'black',
                        ax = ax, legend=True)

plt.title('Total Population 2015', fontsize = 14)
ax.axis('off');

# %%
fl_pub_beach_access = gpd.read_file("../data/Florida_Public_Beach_Access_Sites.shp")

# %%
fl_pub_beach_access.shape
# Out:
# (2195, 49)

# %%
fl_pub_beach_access.head()
# Out:
#      COUNTY             BEACH_OR_C             ACCESS_NAM  X_LONGITUD  \
# 0       Bay           Mexico Beach            16th Street  -85.408064
# 1       Bay           Mexico Beach            17th Street  -85.409006
# 2       Bay           Mexico Beach            21st Street  -85.412331
# 3       Bay           Mexico Beach            23rd Street  -85.413925
# 4  Escambia  Big Lagoon State Park  Big Lagoon State Park  -87.421912
#
#    Y_LATITUDE                                LOCATION_A  FEET_OF_FR  \
# 0   29.940748                       16th Street & US 98        35.0
# 1   29.941412                       17th Street & US 98        40.0
# 2   29.943779    south end of 21 Street; south of US 98        40.0
# 3   29.944461  south end of 23rd Street; south of US 98        40.0
# 4   30.311739                  12301 Gulf Beach Highway         0.0
#
#   PANHANDLE_ GULF_COAST ATLANTIC_C  ... OTHER PUBLIC_WEB WEB_URL SITE_ID  \
# ...

# %%
fl_pub_beach_access.plot()
# Out:
# <AxesSubplot:>

# %%
fl_pub_beach_access.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
fig, ax = plt.subplots(figsize=(20,20),
                      edgecolor = 'black') 
fl_pub_beach_access.plot(ax = ax);

# %%
fl_water_supply_planning_regions = gpd.read_file("../data/Florida_Regional_Water_Supply_Planning_Regions.shp")

# %%
fl_water_supply_planning_regions.shape
# Out:
# (19, 11)

# %%
fl_water_supply_planning_regions.head()
# Out:
#   DISTRICT                    REGION  \
# 0    SRWMD  SRWMD (excluding NFRWSP)
# 1    SFWMD           Lower Kissimmee
# 2    SFWMD          Upper East Coast
# 3    SFWMD          Lower West Coast
# 4    SFWMD          Lower East Coast
#
#                                             COUNTIES RWSP  \
# 0  Dixie, Jefferson, Lafayette, Levy, Taylor, Mad...   No
# 1                      Highlands, Okeechobee, Glades  Yes
# 2                      Okeechobee, St. Lucie, Martin  Yes
# 3    Hendry, Glades, Monroe, Lee, Collier, Charlotte  Yes
# 4  Hendry, Broward, Palm Beach, Miami-Dade, Monro...  Yes
#
#                                            RWSP_LINK         LABEL  \
# 0                                                N/A  SR EX-NFRWSP
# 1  https://www.sfwmd.gov/our-work/water-supply/lo...        SF LKB
# 2  https://www.sfwmd.gov/our-work/water-supply/up...        SF UEC
# 3  https://www.sfwmd.gov/our-work/water-supply/lo...        SF LWC
# ...

# %%
fl_water_supply_planning_regions.plot()
# Out:
# <AxesSubplot:>

# %%
fl_water_supply_planning_regions.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
fig, ax = plt.subplots(figsize=(20,20),
                      edgecolor = 'black') 
fl_water_supply_planning_regions.plot(ax = ax);

# %%
fl_dams = gpd.read_file("../data/Florida_Dams.shp")

# %%
fl_dams.shape
# Out:
# (1110, 71)

# %%
fl_dams.head()
# Out:
#    RECORDID         DAM_NAME          OTHER_DAM_ DAM_FORMER STATEID    NIDID  \
# 0      8406    JACKSON BLUFF  LAKE TALQUIN (RES)       None    None  FL00108
# 1      8407      REMOTE DIKE                None       None    None  FL00108
# 2      8408    TALLAVANA DAM                None       None    None  FL00109
# 3      8409  LAKE YVETTE DAM                None       None    None  FL00110
# 4      8410        PEAVY DAM                None       None    None  FL00111
#
#    LONGITUDE  LATITUDE     SECTION_   COUNTY  ... OTHERSTRUC OBJECTID  \
# 0   -84.6464   30.3879  S17 T1S R3W     LEON  ...       None        1
# 1   -84.6493   30.4005  S17 T1S R3W  GADSDEN  ...       S001        2
# 2   -84.4703   30.5941   S6 T2N R2W  GADSDEN  ...       None        3
# 3   -84.4697   30.5304  S31 T2N R2W  GADSDEN  ...       None        4
# 4   -84.4177   30.6757  S10 T3N R2W  GADSDEN  ...       None        5
#
#   DAM_DESIGN NUMSEPARAT PERMITTING INSPECTI_2 ENFORCEMEN JURISDICTI  \
# ...

# %%
fl_dams.plot()
# Out:
# <AxesSubplot:>

# %%
fl_dams.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
fig, ax = plt.subplots(figsize=(20,20),
                      edgecolor = 'black') 
fl_dams.plot(ax = ax);
